# %%
import sys
import tensorflow as tf
import tensorflow.keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers.convolutional import Conv2D, MaxPooling2D
import numpy as np
np.random.seed(7)
img_rows = 28
img_cols = 28

# MNIST 데이터셋 읽어오기
(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()

# 데이터 reshape
input_shape = (img_rows, img_cols, 1)
x_train = x_train.reshape(x_train.shape[0], img_rows, img_cols, 1)
x_test = x_test.reshape(x_test.shape[0], img_rows, img_cols, 1)

# x데이터 정규화 y데이터 벡터화
x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.

print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')

num_classes = 10

y_train = tensorflow.keras.utils.to_categorical(y_train, num_classes)
y_test = tensorflow.keras.utils.to_categorical(y_test, num_classes)

# CNN 모델 구축
model = Sequential()
model.add(Conv2D(32, kernel_size=(5, 5), strides=(1, 1), padding='same', activation='relu', input_shape=input_shape))
model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
model.add(Conv2D(64, (2, 2), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(1000, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))
print(model.summary())

# 모델 학습
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
hist = model.fit(x_train, y_train, batch_size=256, epochs=30, verbose=1, validation_data=(x_test, y_test))

score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])

# 모델 저장
model.save('MNIST_CNN_model_epochs30.h5')
# Out:
# x_train shape: (60000, 28, 28, 1)
# 60000 train samples
# 10000 test samples
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_8 (Conv2D)           (None, 28, 28, 32)        832
#
#  max_pooling2d_8 (MaxPooling  (None, 14, 14, 32)       0
#  2D)
#
#  conv2d_9 (Conv2D)           (None, 14, 14, 64)        8256
#
#  max_pooling2d_9 (MaxPooling  (None, 7, 7, 64)         0
#  2D)
#
#  dropout_4 (Dropout)         (None, 7, 7, 64)          0
#
#  flatten_4 (Flatten)         (None, 3136)              0
#
#  dense_8 (Dense)             (None, 1000)              3137000
#
#  dropout_5 (Dropout)         (None, 1000)              0
#
#  dense_9 (Dense)             (None, 10)                10010
#
# =================================================================
# Total params: 3,156,098
# Trainable params: 3,156,098
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/30
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x000001D63D51F9D8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x000001D63D51F9D8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 234/235 [============================>.] - ETA: 0s - loss: 0.2399 - accuracy: 0.9271WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x000001D6313C5288> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x000001D6313C5288> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 235/235 [==============================] - 14s 59ms/step - loss: 0.2397 - accuracy: 0.9272 - val_loss: 0.0584 - val_accuracy: 0.9816
# Epoch 2/30
# 235/235 [==============================] - 14s 59ms/step - loss: 0.0665 - accuracy: 0.9791 - val_loss: 0.0335 - val_accuracy: 0.9894
# Epoch 3/30
# 235/235 [==============================] - 14s 60ms/step - loss: 0.0494 - accuracy: 0.9843 - val_loss: 0.0299 - val_accuracy: 0.9894
# Epoch 4/30
# 235/235 [==============================] - 14s 59ms/step - loss: 0.0408 - accuracy: 0.9873 - val_loss: 0.0316 - val_accuracy: 0.9900
# Epoch 5/30
# 235/235 [==============================] - 14s 59ms/step - loss: 0.0335 - accuracy: 0.9893 - val_loss: 0.0235 - val_accuracy: 0.9919
# Epoch 6/30
# 235/235 [==============================] - 14s 59ms/step - loss: 0.0291 - accuracy: 0.9908 - val_loss: 0.0249 - val_accuracy: 0.9922
# Epoch 7/30
# 235/235 [==============================] - 14s 59ms/step - loss: 0.0275 - accuracy: 0.9912 - val_loss: 0.0212 - val_accuracy: 0.9926
# Epoch 8/30
# 235/235 [==============================] - 14s 59ms/step - loss: 0.0227 - accuracy: 0.9928 - val_loss: 0.0221 - val_accuracy: 0.9926
# Epoch 9/30
# 235/235 [==============================] - 14s 59ms/step - loss: 0.0190 - accuracy: 0.9934 - val_loss: 0.0224 - val_accuracy: 0.9930
# Epoch 10/30
# 235/235 [==============================] - 14s 59ms/step - loss: 0.0182 - accuracy: 0.9943 - val_loss: 0.0198 - val_accuracy: 0.9940
# Epoch 11/30
# 235/235 [==============================] - 14s 60ms/step - loss: 0.0171 - accuracy: 0.9945 - val_loss: 0.0257 - val_accuracy: 0.9909
# Epoch 12/30
# 235/235 [==============================] - 14s 59ms/step - loss: 0.0162 - accuracy: 0.9946 - val_loss: 0.0179 - val_accuracy: 0.9946
# Epoch 13/30
# 235/235 [==============================] - 14s 58ms/step - loss: 0.0160 - accuracy: 0.9946 - val_loss: 0.0222 - val_accuracy: 0.9934
# Epoch 14/30
# 235/235 [==============================] - 14s 58ms/step - loss: 0.0130 - accuracy: 0.9958 - val_loss: 0.0186 - val_accuracy: 0.9944
# Epoch 15/30
# 235/235 [==============================] - 14s 59ms/step - loss: 0.0125 - accuracy: 0.9955 - val_loss: 0.0214 - val_accuracy: 0.9938
# Epoch 16/30
# 235/235 [==============================] - 14s 61ms/step - loss: 0.0100 - accuracy: 0.9966 - val_loss: 0.0209 - val_accuracy: 0.9938
# Epoch 17/30
# 235/235 [==============================] - 14s 60ms/step - loss: 0.0096 - accuracy: 0.9965 - val_loss: 0.0218 - val_accuracy: 0.9931
# Epoch 18/30
# 235/235 [==============================] - 14s 60ms/step - loss: 0.0102 - accuracy: 0.9968 - val_loss: 0.0216 - val_accuracy: 0.9942
# Epoch 19/30
# 235/235 [==============================] - 14s 61ms/step - loss: 0.0104 - accuracy: 0.9965 - val_loss: 0.0230 - val_accuracy: 0.9931
# Epoch 20/30
# 235/235 [==============================] - 14s 60ms/step - loss: 0.0092 - accuracy: 0.9969 - val_loss: 0.0239 - val_accuracy: 0.9930
# Epoch 21/30
# 235/235 [==============================] - 14s 59ms/step - loss: 0.0083 - accuracy: 0.9973 - val_loss: 0.0231 - val_accuracy: 0.9939
# Epoch 22/30
# 235/235 [==============================] - 14s 60ms/step - loss: 0.0101 - accuracy: 0.9961 - val_loss: 0.0248 - val_accuracy: 0.9932
# Epoch 23/30
# 235/235 [==============================] - 14s 59ms/step - loss: 0.0082 - accuracy: 0.9974 - val_loss: 0.0199 - val_accuracy: 0.9940
# Epoch 24/30
# 235/235 [==============================] - 14s 59ms/step - loss: 0.0069 - accuracy: 0.9977 - val_loss: 0.0218 - val_accuracy: 0.9940
# Epoch 25/30
# 235/235 [==============================] - 14s 61ms/step - loss: 0.0071 - accuracy: 0.9978 - val_loss: 0.0227 - val_accuracy: 0.9944
# Epoch 26/30
# 235/235 [==============================] - 14s 61ms/step - loss: 0.0082 - accuracy: 0.9973 - val_loss: 0.0260 - val_accuracy: 0.9940
# Epoch 27/30
# 235/235 [==============================] - 15s 62ms/step - loss: 0.0077 - accuracy: 0.9975 - val_loss: 0.0201 - val_accuracy: 0.9952
# Epoch 28/30
# 235/235 [==============================] - 15s 62ms/step - loss: 0.0063 - accuracy: 0.9979 - val_loss: 0.0234 - val_accuracy: 0.9935
# Epoch 29/30
# 235/235 [==============================] - 15s 63ms/step - loss: 0.0070 - accuracy: 0.9974 - val_loss: 0.0192 - val_accuracy: 0.9953
# Epoch 30/30
# 235/235 [==============================] - 14s 61ms/step - loss: 0.0052 - accuracy: 0.9982 - val_loss: 0.0232 - val_accuracy: 0.9950
# Test loss: 0.023216234520077705
# Test accuracy: 0.9950000047683716
